# %%
import torch
import torch.nn as nn
class PositionalEncoding(nn.Module):

    def __init__(self, hidden, dropout = 0.1, max_len = 256):
        super().__init__()
        self.dropout = nn.Dropout(p=dropout)
        position = torch.arange(max_len).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, hidden, 2) * (-np.log(10000.0) / hidden))
        pe = torch.zeros(max_len, 1, hidden)
        pe[:, 0, 0::2] = torch.sin(position * div_term)
        pe[:, 0, 1::2] = torch.cos(position * div_term)
        self.register_buffer('pe', pe)

    def forward(self, x):
        """
        Args:
            x: Tensor, shape [seq_len, batch_size, embedding_dim]
        """
        print(self.pe.shape)
        print(self.pe[:x.size(0)].shape)
        print(self.pe[:x.size(0)][0,1,])
        print(self.pe[:x.size(0)][1,2,])
        x = x + self.pe[:x.size(0)]
        return self.dropout(x)

# %%
a = torch.randn(2,256,512)

# %%
import numpy as np
pe = PositionalEncoding(512)

# %%
b=pe(a)
# Out:
# torch.Size([256, 1, 512])
# torch.Size([2, 1, 512])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 b=pe(a)
#
# File /local2/zjx/anaconda3/corigami1/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[46], line 22, in PositionalEncoding.forward(self, x)
#      20 print(self.pe.shape)
#      21 print(self.pe[:x.size(0)].shape)
# ---> 22 print(self.pe[:x.size(0)][0,1,])
#      23 print(self.pe[:x.size(0)][1,2,])
#      24 x = x + self.pe[:x.size(0)]
#
# IndexError: index 1 is out of bounds for dimension 1 with size 1
